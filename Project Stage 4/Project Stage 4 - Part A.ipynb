# %% [markdown]
# # Project Stage 3: Entity Matching#
#
# The entity we performed our match was on a set of restaurants in New York City. The data for the tables was taken from two different web sources, namely, Tripadvisor and Yelp.
#
# We used the py_entitymatching package to help in this process.

# %%
# Import py_entitymatching package
import py_entitymatching as em
import os
import pandas as pd

# %% [markdown]
# ## Reading in Input Tables##
#
# We read the CSV files and set 'ID' as the key attribute.
#
# Input table A corresponds to data from TripAdvisor, and input table B corresponds to data from Yelp.

# %%
path_A = 'C:\\Users\\bharg\\Documents\\TripAdvisor_Restaurants.csv'
path_B = 'C:\\Users\\bharg\\Documents\\Yelp_Restaurants.csv'
#path_A = 'C:\\Users\\Aribhit\\TripAdvisor_Restaurants.csv'
#path_B = 'C:\\Users\\Aribhit\\Yelp_Restaurants.csv'

# %%
A = em.read_csv_metadata(path_A, key='Id', encoding = 'cp1252')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
B = em.read_csv_metadata(path_B, key='Id', encoding = 'cp1252')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %% [markdown]
# # Data Pre-processing#
#
# Since there was a lot of variance in how *Address* attribute was defined, created a new attribute called *Street* that is extracted from *Address* (by considering the part of the string till the state appears).
#
# Also converted every string type attribute to lower case.

# %%
A['Street'] = A.apply(lambda row : row['Address'][0:row['Address'].find('New')],axis=1)
A['Name']=A['Name'].str.lower()
A['Street']=A['Street'].str.lower()
A['Address']=A['Address'].str.lower()

# %%
def cleaning(row) :
    for string in ['New','Jersey','NY','NJ']:
        index = row['Address'].find(string)
        if index == -1 :
            continue
        return row['Address'][0:index]
    return row['Address']
    
B['Street'] = B.apply(cleaning,axis =1)
B['Name']=B['Name'].str.lower()
B['Street']=B['Street'].str.lower()
B['Address']=B['Address'].str.lower()

# %% [markdown]
# Deleting *Phone* attribute in case it might act as an unique ID and game the system

# %%
#A1 = A.copy(deep=True)
#B1 = B.copy(deep=True)
#del A['Phone']
#del B['Phone']

# %% [markdown]
# ## Applying the Blocker##
#
# We have used the combination of two blockers:
# One blocks based on *Name* of the restaurant (Jaccard Measure with 3 grams with a constraint 0.3) and *Street* (Jaccard Measure with 3 grams with a constraint 0.3).
# Next blocker is only on the *Street* attribute(Jaccard Measure with 3 grams with a constraint 0.6).
#
# We use these blockers and then combine the results of two different blockers using union for the following reasons.
# *Street* (from *Address*) only because it can capture some pairs where names are same but differ by a new word. Ex. (alfa ristorante, alfa). The constraint is higher - 0.6
# *Name* only to capture restaurants that have similar names (constraint is 0.3). But added *Street* based rule on top of that to eliminate chain restaurants with multiple branches at different locations (eg: Shake shacks at Manhattan, Shake Shacks at Brooklyn). The constraint is lower threshold in this case compared to the earlier blocker.
#
# First, get all possible features for blocking.

# %%
block_f = em.get_features_for_blocking(A, B, validate_inferred_attr_types=False)

# %% [markdown]
# First rule-based blocker uses *Name* and *Street* attributes

# %%
rb = em.RuleBasedBlocker()
ab = em.AttrEquivalenceBlocker()
rb.add_rule(['Name_Name_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.5'], block_f)
rb.add_rule(['Street_Street_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.3'], block_f)
# Out:
# '_rule_1'

# %%
C = rb.block_tables(A, B, l_output_attrs=['Name', 'Street', 'Address','Cuisines','Take Out','Phone',
                                          'Saturday Opening time','Saturday Closing time','Sunday Opening time',
                                          'Sunday Closing time'], 
                    r_output_attrs=['Name', 'Street', 'Address','Cuisines','Take Out','Phone',
                                          'Saturday Opening time','Saturday Closing time','Sunday Opening time',
                                          'Sunday Closing time'], show_progress=True)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Finding pairs with missing value...
# Total time elapsed: 00:00:01
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %% [markdown]
# Second rule-based blocker uses only *Street* attribute

# %%
rb2 = em.RuleBasedBlocker()
rb2.add_rule(['Street_Street_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.6'], block_f)
E = rb2.block_tables(A, B, l_output_attrs=['Name', 'Street', 'Address','Cuisines','Take Out','Phone',
                                          'Saturday Opening time','Saturday Closing time','Sunday Opening time',
                                          'Sunday Closing time'], 
                     r_output_attrs=['Name', 'Street', 'Address','Cuisines','Take Out','Phone',
                                          'Saturday Opening time','Saturday Closing time','Sunday Opening time',
                                          'Sunday Closing time'], n_jobs=-1,show_progress=True)
# Out:
# Finding pairs with missing value...

# %% [markdown]
# Combining blocker1 and blocker2 results to get candidate set C (which is named F in our code).

# %%
F = em.combine_blocker_outputs_via_union([C, E])

# %% [markdown]
# Running debugger to see if F is good. 41/50 outputs of debugger are bad matches.Therefore we are proceeding with the above
# blocker

# %%
dbg = em.debug_blocker(F, A, B, output_size=50)
dbg.head()
# Out:
#    _id  ltable_Id  rtable_Id              ltable_Name  \
# 0    0       1308       1183  razza pizza artigianale
# 1    1       2076       2436                 sandro's
# 2    2       1974       3094              strip house
# 3    3       3174       2890             porter house
# 4    4       2322       2861    salon de ning rooftop
#
#                                           ltable_Address  \
# 0                275 grove st jersey city, nj 07302-3601
# 1             306 e 81st st new york city, ny 10028-3984
# 2              13 e 12th st new york city, ny 10003-4404
# 3     10 columbus cir ste 4 new york city, ny 10019-1210
# 4  700 5th avenue at 55th street new york city, ny 10019
#
#                            ltable_Cuisines ltable_Saturday Opening time  \
# 0        Italian;Pizza;Vegetarian Friendly                     05:30 PM
# 1                                  Italian                     05:00 PM
# 2  American;Steakhouse;Gluten Free Options                     05:00 PM
# 3                American;Steakhouse;Grill                     11:30 AM
# 4                             American;Bar                     05:00 PM
#
#   ltable_Saturday Closing time ltable_Sunday Opening time  \
# 0                     10:30 PM                        NaN
# 1                     11:00 PM                   04:30 PM
# 2                     11:30 PM                   05:00 PM
# 3                     11:00 PM                   11:00 AM
# 4                     01:00 AM                   05:00 PM
#
#   ltable_Sunday Closing time               ...                \
# 0                        NaN               ...
# 1                   10:00 PM               ...
# 2                   10:00 PM               ...
# 3                   10:00 PM               ...
# 4                   12:00 AM               ...
#
#                             ltable_Street                 rtable_Name  \
# 0  275 grove st jersey city, nj 07302-360     razza pizza artigianale
# 1                          306 e 81st st               antonucci cafe
# 2                           13 e 12th st        strip house speakeasy
# 3                  10 columbus cir ste 4   porter house bar and grill
# 4          700 5th avenue at 55th street                salon de ning
#
#                                     rtable_Address  \
# 0                 275 grove stjersey city nj 07302
# 1                   170 e 81st stnew york ny 10028
# 2                    11 e 12th stnew york ny 10003
# 3                 10 columbus cirnew york ny 10019
# 4  700 5th avethe peninsula hotelnew york ny 10019
#
#                             rtable_Cuisines rtable_Saturday Opening time  \
# 0                             Italian;Salad                     05:30 PM
# 1                                   Italian                     12:00 PM
# 2                               Steakhouses                     05:00 PM
# 3  Steakhouses;American (New);Cocktail Bars                     11:30 AM
# 4                     Lounges;Cocktail Bars                     05:00 PM
#
#   rtable_Saturday Closing time rtable_Sunday Opening time  \
# 0                     10:00 PM                     CLOSED
# 1                     11:00 PM                   12:00 PM
# 2                     11:30 PM                     CLOSED
# 3                     11:00 PM                   11:30 AM
# 4                     01:00 AM                   04:00 PM
#
#   rtable_Sunday Closing time rtable_Take Out                   rtable_Street
# 0                     CLOSED             Yes                    275 grove st
# 1                   10:00 PM             Yes                   170 e 81st st
# 2                     CLOSED              No                    11 e 12th st
# 3                   10:00 PM              No                 10 columbus cir
# 4                   12:00 AM              No  700 5th avethe peninsula hotel
#
# [5 rows x 21 columns]

# %%
F.to_csv("F.csv",index=False,encoding = 'cp1252')

# %%
F.shape
# Out:
# (1625, 23)

# %%
F.head()
# Out:
#    _id ltable_Id rtable_Id           ltable_Name        ltable_Street  \
# 0    0         6      1428  shanghai asian manor          21 mott st
# 1    1        11      1489           shake shack    366 columbus ave
# 2    2        15       606             blue maiz         606 8th ave
# 3    3        21      1019          dutch fred's       307 w 47th st
# 4    4        26      1972         pret a manger  30 rockefeller plz
#
#                                     ltable_Address  \
# 0          21 mott st new york city, ny 10013-5032
# 1    366 columbus ave new york city, ny 10024-5109
# 2         606 8th ave new york city, ny 10018-3008
# 3       307 w 47th st new york city, ny 10036-2403
# 4  30 rockefeller plz new york city, ny 10112-0015
#
#                      ltable_Cuisines ltable_Take Out     ltable_Phone  \
# 0  Chinese;Asian;Vegetarian Friendly             Yes  +1 212-766-6311
# 1                 American;Fast Food             Yes  +1 646-747-8770
# 2            Mexican;Latin;Fast Food             Yes  +1 212-704-2106
# 3                   American;Bar;Pub              No  +1 646-918-6923
# 4            American;Cafe;Fast Food             Yes  +1 212-246-6944
#
#   ltable_Saturday Opening time            ...              \
# 0                     11:00 AM            ...
# 1                     10:30 AM            ...
# 2                     11:00 AM            ...
# 3                          NaN            ...
# 4                          NaN            ...
#
#             rtable_Name            rtable_Street  \
# 0  shanghai asian manor               21 mott st
# 1           shake shack         366 columbus ave
# 2             blue maiz              606 8th ave
# 3           dutch freds            307 w 47th st
# 4         bar sixtyfive  30 rockefeller plzfl 65
#
#                              rtable_Address  \
# 0               21 mott stnew york ny 10013
# 1         366 columbus avenew york ny 10024
# 2              606 8th avenew york ny 10018
# 3            307 w 47th stnew york ny 10036
# 4  30 rockefeller plzfl 65new york ny 10112
#
#                                       rtable_Cuisines rtable_Take Out  \
# 0                                        Shanghainese             Yes
# 1                              Burgers;American (New)             Yes
# 2                                             Mexican             Yes
# 3            Cocktail Bars;Pubs;Venues & Event Spaces              No
# 4  Cocktail Bars;Venues & Event Spaces;American (New)              No
#
#      rtable_Phone rtable_Saturday Opening time rtable_Saturday Closing time  \
# 0  (212) 766-6311                     11:00 AM                     10:00 PM
# 1  (646) 747-8770                     10:30 AM                     11:00 PM
# 2  (212) 704-2106                     11:00 AM                     10:00 PM
# 3  (646) 918-6923                     11:00 AM                     04:00 AM
# 4  (212) 632-5000                       CLOSED                       CLOSED
#
#   rtable_Sunday Opening time rtable_Sunday Closing time
# 0                   11:00 AM                   09:00 PM
# 1                   10:30 AM                   11:00 PM
# 2                   11:00 AM                   09:00 PM
# 3                   11:00 AM                   04:00 AM
# 4                   04:00 PM                   09:00 PM
#
# [5 rows x 23 columns]

# %% [markdown]
# Taking a sample of 600 tuples from the output, and then we label this sample manually.

# %%
S = em.sample_table(F, 600)
S.to_csv('Sample.csv',encoding = 'cp1252')

# %% [markdown]
# ## Reading the Labelled Sample##
# Loading the labeled data table, which is present in a file called 'Labelled_Sample_v2.csv'

# %%
L = em.read_csv_metadata("Labelled_Sample_v2.csv", key='_id', encoding = 'cp1252',\
                         ltable=A, rtable=B,fk_ltable='ltable_Id', fk_rtable='rtable_Id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %% [markdown]
# Deleting *Phone* attribute again, because it can help determine matches trivially.

# %%
del L['ltable_Phone']
del L['rtable_Phone']

# %% [markdown]
# ## Splitting the Labelled Set##
#
# Splitting the labelled set into training and test set, by putting half the tuple pairs in each.<br>
# The development set is called I<br>
# The evaluation set is called J

# %%
IJ = em.split_train_test(L, train_proportion=0.5, random_state=0)
I = IJ['train']
J = IJ['test']
I.to_csv('I.csv',encoding = 'cp1252')
J.to_csv('J.csv',encoding = 'cp1252')

# %%
J.head()
# Out:
#       _id  ltable_Id  rtable_Id                        ltable_Name  \
# 434  1164       2882       3032                  iridium jazz club
# 122   319        778       2666  mykonos blue restaurant & rooftop
# 224   603       1522        599                     noodle village
# 479  1290       3111       1845                   parker and quinn
# 205   540       1350       1949                          moustache
#
#       ltable_Street                              ltable_Address  \
# 434  1650 broadway   1650 broadway new york city, ny 10019-6833
# 122  127 w 28th st   127 w 28th st new york city, ny 10001-6102
# 224     13 mott st      13 mott st new york city, ny 10013-5025
# 479   63 w 39th st    63 w 39th st new york city, ny 10018-3801
# 205  90 bedford st   90 bedford st new york city, ny 10014-3764
#
#         ltable_Phone                        ltable_Cuisines ltable_Take Out  \
# 434  +1 212-582-2121                       American;Bar;Pub              No
# 122  +1 646-484-4339            Mediterranean;Greek;Seafood              No
# 224  +1 212-233-0788      Chinese;Asian;Vegetarian Friendly             Yes
# 479  +1 212-729-0277       American;Bar;Vegetarian Friendly             Yes
# 205  +1 212-229-2220  Lebanese;Mediterranean;Middle Eastern             Yes
#
#         rtable_Name  rtable_Street                  rtable_Address  \
# 434     the iridium  1650 broadway  1650 broadwaynew york ny 10019
# 122    mykonos blue  127 w 28th st  127 w 28th stnew york ny 10001
# 224  noodle village     13 mott st     13 mott stnew york ny 10013
# 479  parker & quinn   64 w 39th st   64 w 39th stnew york ny 10018
# 205  the little owl  90 bedford st  90 bedford stnew york ny 10014
#
#        rtable_Phone                         rtable_Cuisines rtable_Take Out  \
# 434  (347) 815-8649             Jazz & Blues;American (New)              No
# 122  (347) 979-0451                                   Greek             Yes
# 224  (212) 233-0788                         Chinese;Noodles             Yes
# 479  (212) 729-0277  American (New);Bars;Breakfast & Brunch             Yes
# 205  (212) 741-4695        Desserts;Wine Bars;Mediterranean             Yes
#
#      label
# 434      1
# 122      1
# 224      1
# 479      1
# 205      0

# %% [markdown]
# ## Creating ML-matchers##
#
# Initiating 6 different classifiers (Decision Tree, Random Forest, SVM, Naive Bayes, Logistic Regression, Linear Regression) and then, cross validating them on I set.

# %%
dt = em.DTMatcher(name='DecisionTree', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
nb = em.NBMatcher(name ='NaiveBayes')
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')

# %% [markdown]
# ## Selecting Best Matcher ##
#
# First, we obtain all the features we could use for matching. Ft is our feature table

# %%
Ft = em.get_features_for_matching(A, B, validate_inferred_attr_types=False)

# %% [markdown]
# Use the system to generate feature vectors from set I. This is called set H

# %%
H = em.extract_feature_vecs(I, 
                            feature_table=Ft, 
                            attrs_after='label',
                            show_progress=False)

# %% [markdown]
# Perform matches and display results below (after performing cross-validation)

# %%
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_Id', 'rtable_Id', 'label'],
                strategy='mean')

# %%
result = em.select_matcher([dt, rf, svm, ln, lg,nb], table=H, 
        exclude_attrs=['_id', 'ltable_Id', 'rtable_Id', 'label'],
        k=5,
        target_attr='label', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.966529        0.969566    0.967772
# 1            RF           0.965328        0.969566    0.967215
# 2           SVM           0.827648        0.995455    0.902929
# 3        LinReg           0.969032        0.954895    0.961627
# 4        LogReg           0.976138        0.969460    0.972647
# 5    NaiveBayes           0.975238        0.974112    0.974515

# %% [markdown]
# Picking Random Forest as it has the highest average F1 score. We are not adding any rule based matchers as the precision,recall and F1 scores are already above the required thresholds.

# %% [markdown]
# ## Evaluating Best Matcher##
#
# As we picked Random Forest as the best matcher, now we apply it on the evaluation set (set J; defined earlier) to find how well it performs.
#
# Create a new Random Forest matcher and train it on set H (feature table obtained from set I):

# %%
rf = em.RFMatcher(name='RF', random_state=0)

# %%
rf.fit(table=H, 
       exclude_attrs=['_id', 'ltable_Id', 'rtable_Id', 'label'], 
       target_attr='label')

# %%
Test_Ft = em.read_csv_metadata("F.csv", key='_id', encoding = 'cp1252',\
                         ltable=A, rtable=B,fk_ltable='ltable_Id', fk_rtable='rtable_Id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %% [markdown]
# Extracting features from set J:

# %%
Test_Ft = em.extract_feature_vecs(Test_Ft, feature_table=Ft,
                             show_progress=False)

# %%
Test_Ft = Test_Ft.dropna(axis =0,how ='any')
Test_Ft.to_csv("Test_Ft.csv",index=False)

# %%
Test_Ft = em.read_csv_metadata("Test_Ft.csv", key='_id', encoding = 'cp1252',\
                         ltable=A, rtable=B,fk_ltable='ltable_Id', fk_rtable='rtable_Id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
Test_Ft.head()
# Out:
#    _id  ltable_Id  rtable_Id  Id_Id_exm  Id_Id_anm  Id_Id_lev_dist  \
# 0    0          6       1428          0   0.004202               4
# 1    1         11       1489          0   0.007388               3
# 2    2         15        606          0   0.024752               3
# 3    8         29       1231          0   0.023558               3
# 4    9         32       2719          0   0.011769               4
#
#    Id_Id_lev_sim  Name_Name_jac_qgm_3_qgm_3  Name_Name_cos_dlm_dc0_dlm_dc0  \
# 0           0.00                        1.0                            1.0
# 1           0.25                        1.0                            1.0
# 2           0.00                        1.0                            1.0
# 3           0.25                        1.0                            1.0
# 4           0.00                        1.0                            1.0
#
#    Name_Name_jac_dlm_dc0_dlm_dc0        ...         Take_Out_Take_Out_exm  \
# 0                            1.0        ...                             1
# 1                            1.0        ...                             1
# 2                            1.0        ...                             1
# 3                            1.0        ...                             1
# 4                            1.0        ...                             1
#
#    Take_Out_Take_Out_jac_qgm_3_qgm_3  Street_Street_jac_qgm_3_qgm_3  \
# 0                                1.0                       0.666667
# 1                                1.0                       0.761905
# 2                                1.0                       0.687500
# 3                                1.0                       0.705882
# 4                                1.0                       0.451613
#
#    Street_Street_cos_dlm_dc0_dlm_dc0  Street_Street_jac_dlm_dc0_dlm_dc0  \
# 0                                1.0                           1.000000
# 1                                1.0                           1.000000
# 2                                1.0                           1.000000
# 3                                1.0                           1.000000
# 4                                0.5                           0.333333
#
#    Street_Street_mel  Street_Street_lev_dist  Street_Street_lev_sim  \
# 0           0.981818                       1               0.909091
# 1           0.988235                       1               0.941176
# 2           0.983333                       1               0.916667
# 3           0.984615                       1               0.923077
# 4           0.870813                       6               0.727273
#
#    Street_Street_nmw  Street_Street_sw
# 0                9.0              10.0
# 1               15.0              16.0
# 2               10.0              11.0
# 3               11.0              12.0
# 4               13.0              16.0
#
# [5 rows x 82 columns]

# %% [markdown]
# Computing predictions on set J:

# %%
predictions = rf.predict(table=Test_Ft, exclude_attrs=['_id', 'ltable_Id', 'rtable_Id'], 
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')

# %%
predictions[['_id', 'ltable_Id', 'rtable_Id', 'predicted', 'proba']]
# Out:
#        _id  ltable_Id  rtable_Id  predicted  proba
# 0        0          6       1428          1    1.0
# 1        1         11       1489          1    1.0
# 2        2         15        606          1    1.0
# 3        8         29       1231          1    1.0
# 4        9         32       2719          1    0.9
# 5       10         33       1589          1    0.9
# 6       12         48       2167          1    0.9
# 7       13         51       2397          1    1.0
# 8       14         55       2505          1    1.0
# 9       15         56        507          1    1.0
# 10      17         67       1700          0    0.0
# 11      18         67       3013          0    0.0
# 12      19         73        424          0    0.1
# 13      23         85       2387          1    1.0
# 14      24         85       3158          0    0.4
# 15      26         87        622          1    1.0
# 16      28         94       2620          1    0.9
# 17      29         99         91          0    0.0
# 18      30         99       2012          1    0.9
# 19      32        114       2295          1    1.0
# 20      33        116       2480          0    0.0
# 21      34        116       3142          1    1.0
# 22      36        124       2470          1    1.0
# 23      37        126       1635          0    0.5
# 24      38        126       2319          0    0.0
# 25      39        126       2320          0    0.5
# 26      40        126       2631          1    0.6
# 27      41        126       2632          0    0.5
# 28      42        127       2434          0    0.1
# 29      43        127       2654          1    1.0
# ...    ...        ...        ...        ...    ...
# 1101  1585       3805       3045          0    0.0
# 1102  1587       3808       2365          1    1.0
# 1103  1588       3810       2731          0    0.0
# 1104  1589       3810       2821          0    0.0
# 1105  1590       3812       2102          1    1.0
# 1106  1591       3818       1630          0    0.0
# 1107  1592       3818       2964          0    0.0
# 1108  1593       3819        965          1    1.0
# 1109  1594       3821       1226          1    1.0
# 1110  1595       3825       2028          1    1.0
# 1111  1596       3839        265          1    1.0
# 1112  1597       3840       2641          1    1.0
# 1113  1598       3841       2070          1    1.0
# 1114  1599       3842       2000          1    1.0
# 1115  1602       3848       2845          1    1.0
# 1116  1603       3849       2068          1    1.0
# 1117  1604       3852       1602          1    1.0
# 1118  1606       3858       2788          0    0.1
# 1119  1609       3861       1507          1    1.0
# 1120  1611       3863        436          0    0.0
# 1121  1612       3863       2382          0    0.0
# 1122  1613       3863       2383          0    0.0
# 1123  1614       3863       2982          0    0.0
# 1124  1615       3866       2164          1    1.0
# 1125  1616       3868       2709          1    1.0
# 1126  1618       3874       2590          0    0.1
# 1127  1619       3877       1640          1    0.9
# 1128  1620       3878        205          1    0.9
# 1129  1621       3882       2275          1    1.0
# 1130  1624       3891        436          0    0.1
#
# [1131 rows x 5 columns]

# %%
ids = predictions['_id'][predictions['predicted']==1]

# %%
ids = ids.tolist()

# %%
F = em.read_csv_metadata("F.csv", key='_id', encoding = 'cp1252',\
                         ltable=A, rtable=B,fk_ltable='ltable_Id', fk_rtable='rtable_Id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
F.shape
# Out:
# (1625, 23)

# %%
F = F[F['_id'].isin(ids)]

# %%
F.shape
# Out:
# (786, 23)

# %%
F.to_csv("project4.csv",index =False)

# %%
F.head(200)
# Out:
#                                  ltable_Name  \
# 0                       shanghai asian manor
# 1                                shake shack
# 2                                  blue maiz
# 8                                barn joo 35
# 9                 southgate bar & restaurant
# 10                                friedman's
# 12                                boulud sud
# 13              rosa mexicano - union square
# 14                           benoit new york
# 15                      the original soupman
# 23                                    limani
# 26                               kung fu tea
# 28                           battery gardens
# 30                                    upland
# 32                         ristorante morini
# 34                                   perrine
# 36                            ninja new york
# 40                             rossopomodoro
# 43                           jams restaurant
# 45                  bailey pub and brasserie
# 54                               zizi limona
# 56                  excellent dumpling house
# 57                                   red cat
# 58                        buttermilk channel
# 60                                   hakubai
# 61                             marlow & sons
# 62                                 sadelle's
# 63                                  asellina
# 64                             victor's cafe
# 65                        the mercer kitchen
# ..                                       ...
# 343                               abc cocina
# 344                               abc cocina
# 345                            club macanudo
# 348                          shun lee palace
# 349                                    catch
# 350                            havana social
# 351                   kang ho dong baekjeong
# 353                         rock center cafe
# 355                           zio ristorante
# 356                               st. anselm
# 357              injera ethiopian restaurant
# 359                        lucien restaurant
# 360                                     jane
# 369                          juliana's pizza
# 370                                  norma's
# 372                  vintry wine and whiskey
# 374                                 joes jr.
# 375                        nino's restaurant
# 376                        hillstone midtown
# 377                                 kingsley
# 380                                calle dao
# 381                                     mimi
# 382            tevere kosher cuisine of rome
# 383                                  porteno
# 384                                 boqueria
# 387                              ray's pizza
# 388                                 suteishi
# 391                                     omen
# 392  clinton st. baking company & restaurant
# 396                                  morandi
#
#                                    ltable_Street  \
# 0                                    21 mott st
# 1                              366 columbus ave
# 2                                   606 8th ave
# 8                                  34 w 35th st
# 9                            154 central park s
# 10                                132 w 31st st
# 12                                 20 w 64th st
# 13                                  9 e 18th st
# 14                                 60 w 55th st
# 15                               259a w 55th st
# 23                           45 rockefeller plz
# 26                               73 chrystie st
# 28                                 battery park
# 30                               345 park ave s
# 32                             1167 madison ave
# 34                                  2 e 61st st
# 36                                 25 hudson st
# 40                                  200 5th ave
# 43                  1414 avenue of the americas
# 45                                52 william st
# 54       129 havemeyer st brooklyn, ny 11211-441
# 56                                165 w 23rd st
# 57                                 227 10th ave
# 58           524 court st brooklyn, ny 11231-401
# 60                                  66 park ave
# 61            81 broadway brooklyn, ny 11249-600
# 62                               463 w broadway
# 63                               420 park ave s
# 64                                236 w 52nd st
# 65                                 99 prince st
# ..                                           ...
# 343                                38 e 19th st
# 344                                38 e 19th st
# 345                                26 e 63rd st
# 348                               155 e 55th st
# 349                                  21 9th ave
# 350                                688 10th ave
# 351                                 1 e 32nd st
# 353                          rockefeller center
# 355                                17 w 19th st
# 356  355 metropolitan ave brooklyn, ny 11211-330
# 357                              11 abingdon sq
# 359                                  14 1st ave
# 360                            100 w houston st
# 369      19 old fulton st brooklyn, ny 11201-132
# 370                               119 w 56th st
# 372                                 57 stone st
# 374                                 167 3rd ave
# 375                                1354 1st ave
# 376                               153 e 53rd st
# 377                                190 avenue b
# 380                                38 w 39th st
# 381                             185 sullivan st
# 382                               155 e 84th st
# 383                                299 10th ave
# 384                               171 spring st
# 387                                27 prince st
# 388                                24 peck slip
# 391                             113 thompson st
# 392                                4 clinton st
# 396                              211 waverly pl
#
#                                                ltable_Address  \
# 0                     21 mott st new york city, ny 10013-5032
# 1               366 columbus ave new york city, ny 10024-5109
# 2                    606 8th ave new york city, ny 10018-3008
# 8                   34 w 35th st new york city, ny 10001-2256
# 9             154 central park s new york city, ny 10019-1510
# 10                 132 w 31st st new york city, ny 10001-3406
# 12                  20 w 64th st new york city, ny 10023-7129
# 13                   9 e 18th st new york city, ny 10003-1903
# 14                  60 w 55th st new york city, ny 10019-5308
# 15                259a w 55th st new york city, ny 10019-5202
# 23            45 rockefeller plz new york city, ny 10111-0100
# 26                73 chrystie st new york city, ny 10002-5034
# 28                       battery park new york city, ny 10004
# 30                345 park ave s new york city, ny 10010-1707
# 32              1167 madison ave new york city, ny 10028-0409
# 34                   2 e 61st st new york city, ny 10065-8401
# 36                  25 hudson st new york city, ny 10013-3802
# 61   +1 718-384-1441                     08:00 AM
# 62   +1 212-776-4926                     08:30 AM
# 63   +1 212-317-2908                     07:00 AM
# 64   +1 212-586-7714                     11:45 AM
# 65   +1 212-966-5454                     07:00 AM
# ..               ...                          ...
# 343  +1 212-475-5829                     05:30 PM
# 344  +1 212-475-5829                     05:30 PM
# 345  +1 212-752-8200                     12:00 PM
# 348  +1 212-371-8844                     12:00 PM
# 349  +1 212-392-5978                     11:00 AM
# 350  +1 212-956-2155                     12:00 PM
# 351  +1 212-966-9839                     11:30 AM
# 353  +1 212-332-7620                     10:00 AM
# 355  +1 212-352-1700                     11:30 AM
# 356     718-384-5054                     05:00 PM
# 357  +1 212-206-9330                     11:30 AM
# 359  +1 212-260-6481                     11:00 AM
# 360  +1 212-254-7000                     09:00 AM
# 369  +1 718-596-6700                     11:30 AM
# 370  +1 212-708-7460                     07:30 AM
# 372  +1 212-480-9800                     12:00 PM
# 374  +1 212-473-5150                     06:00 AM
# 375  +1 212-988-0002                     04:00 PM
# 376  +1 212-888-3828                     12:00 PM
# 377  +1 212-674-4500                     12:00 PM
# 380  +1 212-221-9002                     11:00 AM
# 381  +1 212-418-1260                     06:00 PM
# 382  +1 212-744-0210                     08:00 PM
# 383  +1 212-695-9694                     04:30 PM
# 384  +1 212-343-4255                     11:00 AM
# 387  +1 212-966-1960                     11:00 AM
# 388  +1 212-766-2344                     11:30 AM
# 391  +1 212-925-8923                     06:00 PM
# 392  +1 646-602-6263                     06:00 PM
# 396  +1 212-627-7575                     10:00 AM
#
#     ltable_Saturday Closing time ltable_Sunday Opening time  \
# 0                       10:00 PM                   11:00 AM
# 1                       11:00 PM                   10:30 AM
# 2                       10:00 PM                   11:00 AM
# 8                       02:00 AM                   12:00 PM
# 9                       10:30 PM                   07:00 AM
# 10                      10:00 PM                   08:30 AM
# 12              11:30 PM11:00 AM                   05:00 PM
# 13                      11:30 PM                   11:30 AM
# 14                      11:00 PM                   11:45 AM
# 15                      08:00 PM                   11:00 AM
# 23                      12:00 AM                   12:00 PM
# 26                      10:00 PM                   11:00 AM
# 28                      12:00 AM                   11:30 AM
# 30              11:00 PM10:00 AM                   05:00 PM
# 32                      10:30 PM                   11:30 AM
# 34               10:30 AM5:30 PM                   07:00 AM
# 36                      11:00 PM                   05:00 PM
# 40                      11:00 PM                   09:00 AM
# 43                3:00 PM5:00 PM                   07:00 AM
# 45                      02:00 AM                   08:00 AM
# 54                      11:00 PM                   11:30 AM
# 56                      11:00 PM                   11:00 AM
# 57              11:00 PM11:30 AM                   05:00 PM
# 58              12:00 AM10:00 AM                   05:00 PM
# 60                2:30 PM6:00 PM                   06:00 PM
# 61                4:00 PM5:00 PM                   08:00 AM
# 62                      08:30 PM                   08:30 AM
# 63                      11:30 PM                   07:00 AM
# 64                      12:00 AM                   11:45 AM
# 65                      01:00 AM                   07:00 AM
# ..                           ...                        ...
# 343             12:00 AM11:00 AM                   05:30 PM
# 344             12:00 AM11:00 AM                   05:30 PM
# 345                     02:00 AM                   12:00 PM
# 348                     11:00 PM                   12:00 PM
# 349                     12:00 AM                   11:00 AM
# 350                     12:00 AM                   12:00 PM
# 351                     06:00 AM                   11:30 AM
# 353                     12:00 AM                   10:00 AM
# 355                     11:30 PM                   11:30 AM
# 356                     12:00 PM                   05:00 PM
# 357                     02:00 AM                   11:30 AM
# 359                     02:00 AM                   11:00 AM
# 360                     12:00 AM                   09:00 AM
# 369               3:15 PM4:00 PM                   11:30 AM
# 370                     03:00 PM                   07:30 AM
# 372                     04:00 AM                   12:00 PM
# 374                     11:30 PM                   06:00 AM
# 375                     11:30 PM                   04:00 PM
# 376                     11:00 PM                   12:00 PM
# 377                     12:00 AM                   12:00 PM
# 380                     12:00 AM                   11:00 AM
# 381                     02:00 AM                   12:00 PM
# 382                     11:00 PM                   02:00 PM
# 383                     11:00 PM                   04:30 PM
# 384                     11:30 PM                   11:00 AM
# 387                     12:30 AM                   11:00 AM
# 388                     11:30 PM                   11:30 AM
# 391                     12:00 AM                   06:00 PM
# 392              11:00 PM9:00 AM                   09:00 AM
# 396                     12:00 AM                   10:00 AM
#
#     ltable_Sunday Closing time                     rtable_Name  \
# 0                     09:00 PM            shanghai asian manor
# 1                     11:00 PM                     shake shack
# 2                     09:00 PM                       blue maiz
# 8                     11:00 PM                     barn joo 35
# 9                     10:30 PM      southgate bar & restaurant
# 10                    09:00 PM                      friedman’s
# 12            11:00 PM11:00 AM                      boulud sud
# 13                    04:00 PM                   rosa mexicano
# 14                    11:00 PM                          benoit
# 15                    07:00 PM            the original soupman
# 23                    10:00 PM                          limani
# 26                    10:00 PM                     kung fu tea
# 28                    12:00 AM                 battery gardens
# 30            10:00 PM10:00 AM                          upland
# 32                    09:30 PM               ristorante morini
# 34            10:30 AM12:00 PM                         perrine
# 36                    10:00 PM                  ninja new york
# 40                    11:00 PM                        il pesce
# 43              3:00 PM5:00 PM                            jams
# 45                    02:00 AM    william’s restaurant and bar
# 54                    11:00 PM                     zizi limona
# 56                    10:30 PM        excellent dumpling house
# 57            10:00 PM11:30 AM                     the red cat
# 58            10:00 PM10:00 AM              buttermilk channel
# 60                    10:00 PM                         hakubai
# 61              4:00 PM5:00 PM                   marlow & sons
# 62                    05:00 PM                       sadelle’s
# 63                    10:00 PM                        asellina
# 64                    11:00 PM                   victor’s cafe
# 65                    11:00 PM              the mercer kitchen
# ..                         ...                             ...
# 343           10:30 PM11:00 AM                      abc cocina
# 344           10:30 PM11:00 AM                            abcv
# 345                   10:00 PM                   club macanudo
# 348                   10:30 PM                 shun lee palace
# 349                   11:30 PM                           catch
# 350                   12:00 AM  havana social - hell’s kitchen
# 351                   02:00 AM          kang ho dong baekjeong
# 353                   11:00 PM                rock center cafe
# 355                   11:00 PM                  zio ristorante
# 356                   11:00 PM                      st. anselm
# 357                   12:30 AM                          injera
# 359                   02:00 AM                          lucien
# 360                   10:00 PM                            jane
# 369             3:15 PM4:00 PM                 juliana’s pizza
# 370                   03:00 PM                         norma’s
# 372                   01:00 AM         vintry wine and whiskey
# 374                   11:30 PM              joe jr. restaurant
# 375                   10:00 PM               nino’s restaurant
# 376                   10:00 PM            hillstone restaurant
# 377                   12:00 AM                        kingsley
# 380                   11:00 PM         calle dao - bryant park
# 381                   04:00 PM                            mimi
# 382                   10:00 PM                          tevere
# 383                   10:30 PM              porteno restaurant
# 384                   10:30 PM                        boqueria
# 387                   12:30 AM             prince street pizza
# 388                   10:00 PM                        suteishi
# 391                   12:00 AM                       omen azen
# 392                   06:00 PM   clinton street baking company
# 396                   12:00 AM                         morandi
#
#                      rtable_Street  \
# 0                       21 mott st
# 1                 366 columbus ave
# 2                      606 8th ave
# 8                     34 w 35th st
# 9           160 central park south
# 10                   132 w 31st st
# 12             20 west 64th street
# 13                     9 e 18th st
# 14                    60 w 55th st
# 15                  259a w 55th st
# 23             45 rockerfeller plz
# 26                  73 chrystie st
# 28                  1 battery park
# 30                  345 park ave s
# 32                1167 madison ave
# 34                     2 e 61st st
# 36                    25 hudson st
# 40                     200 5th ave
# 43        1414 ave of the americas
# 45                   52 william st
# 54       129 havemeyer stbrooklyn
# 56                   165 w 23rd st
# 57                    227 10th ave
# 58           524 court stbrooklyn
# 60                     66 park ave
# 61            81 broadwaybrooklyn
# 62                  463 w broadway
# 63                  420 park ave s
# 64                   236 w 52nd st
# 65                    99 prince st
# ..                             ...
# 343                   38 e 19th st
# 344                   38 e 19th st
# 345                   26 e 63rd st
# 348                  155 e 55th st
# 349                21 ninth avenue
# 350                   688 10th ave
# 351                    1 e 32nd st
# 353     rockefeller ctrlower level
# 355                   17 w 19th st
# 356  355 metropolitan avebrooklyn
# 357                 11 abingdon sq
# 359                     14 1st ave
# 360               100 w houston st
# 369      19 old fulton stbrooklyn
# 370                  119 w 56th st
# 372                    57 stone st
# 374                    167 3rd ave
# 375                   1354 1st ave
# 376                  153 e 53rd st
# 377                      190 ave b
# 380                   38 w 39th st
# 381                185 sullivan st
# 382                  155 e 84th st
# 383                   299 10th ave
# 384                  171 spring st
# 387                   27 prince st
# 388                   24 peck slip
# 391                113 thompson st
# 392                   4 clinton st
# 396                 211 waverly pl
#
#                                   rtable_Address  \
# 0                    21 mott stnew york ny 10013
# 1              366 columbus avenew york ny 10024
# 2                   606 8th avenew york ny 10018
# 8                  34 w 35th stnew york ny 10001
# 9        160 central park southnew york ny 10019
# 10                132 w 31st stnew york ny 10001
# 12          20 west 64th streetnew york ny 10023
# 13                  9 e 18th stnew york ny 10003
# 14                 60 w 55th stnew york ny 10019
# 15               259a w 55th stnew york ny 10019
# 23          45 rockerfeller plznew york ny 10111
# 26               73 chrystie stnew york ny 10002
# 28               1 battery parknew york ny 10011
# 30               345 park ave snew york ny 10010
# 32             1167 madison avenew york ny 10028
# 34                  2 e 61st stnew york ny 10065
# 36                 25 hudson stnew york ny 10013
# 40                  200 5th avenew york ny 10010
# 43     1414 ave of the americasnew york ny 10019
# 45                52 william stnew york ny 10005
# 54             129 havemeyer stbrooklyn ny 11211
# 56                165 w 23rd stnew york ny 10011
# 57                 227 10th avenew york ny 10011
# 350                      Cuban;Cocktail Bars;Tapas Bars             Yes
# 351                                     Korean;Barbeque              No
# 353                                      American (New)              No
# 355                               Italian;Mediterranean             Yes
# 356                American (New);Wine Bars;Steakhouses              No
# 357                                      Ethiopian;Bars             Yes
# 359                                    French;Wine Bars              No
# 360              Breakfast & Brunch;American (New);Bars             Yes
# 369                                               Pizza             Yes
# 370                   Breakfast & Brunch;American (New)              No
# 372                              Whiskey Bars;Wine Bars              No
# 374    Diners;Breakfast & Brunch;American (Traditional)             Yes
# 375                                             Italian             Yes
# 376              Jazz & Blues;American (New);Sushi Bars             Yes
# 377              American (New);Cocktail Bars;Wine Bars              No
# 380              Cuban;Cocktail Bars;Breakfast & Brunch             Yes
# 381                                              French              No
# 382                                      Italian;Kosher             Yes
# 383                                           Argentine             Yes
# 384                                             Spanish             Yes
# 387                                               Pizza             Yes
# 388                                 Japanese;Sushi Bars             Yes
# 391                                            Japanese              No
# 392  Bakeries;Breakfast & Brunch;American (Traditional)             Yes
# 396                 Italian;Desserts;Breakfast & Brunch             Yes
#
#        rtable_Phone rtable_Saturday Opening time rtable_Saturday Closing time  \
# 0    (212) 766-6311                     11:00 AM                     10:00 PM
# 1    (646) 747-8770                     10:30 AM                     11:00 PM
# 2    (212) 704-2106                     11:00 AM                     10:00 PM
# 8    (212) 564-4430                     12:00 PM                     01:00 AM
# 9    (210) 491-5845                     07:00 AM                     01:00 AM
# 10   (212) 971-9400                     08:30 AM                     10:00 PM
# 12   (212) 595-1313                     11:00 AM                     11:00 PM
# 13   (212) 533-3350                     11:30 AM                     11:30 PM
# 14   (646) 943-7373                     11:45 AM                     11:00 PM
# 15   (212) 956-0900                     11:00 AM                     08:00 PM
# 23   (212) 858-9200                     12:00 PM                     12:00 AM
# 26   (646) 288-4936                     11:30 AM                     10:00 PM
# 28   (212) 809-5508                     11:30 AM                     07:30 PM
# 30   (212) 686-1006                     10:00 AM                     11:00 PM
# 32   (212) 249-0444                     05:30 PM                     10:30 PM
# 34   (212) 940-8195                     07:30 AM                     10:30 PM
# 36   (212) 274-8500                     05:00 PM                     11:00 PM
# 40   (212) 229-2560                     11:00 AM                     10:00 PM
# 43   (212) 703-2007                     07:00 AM                     11:00 PM
# 45   (212) 859-2200                       CLOSED                       CLOSED
# 54   (347) 763-1463                     11:00 AM                     11:00 PM
# 56   (212) 989-8885                     11:00 AM                     11:00 PM
# 57   (212) 242-1308                     11:30 AM                     11:00 PM
# 58   (718) 852-8490                     10:00 AM                     11:30 PM
# 60   (212) 885-7111                     06:00 PM                     10:00 PM
# 61   (718) 384-1441                     08:00 AM                     12:00 AM
# 62   (212) 776-4926                     08:30 AM                     08:30 PM
# 63   (212) 317-2908                     07:00 AM                     12:30 AM
# 64   (212) 586-7714                     12:00 PM                     12:00 AM
# 65   (212) 966-5454                     07:00 AM                     01:00 AM
# ..              ...                          ...                          ...
# 343  (212) 677-2233                     11:00 AM                     11:30 PM
# 344  (212) 475-5829                     11:00 AM                     11:00 PM
# 345  (212) 752-8200                     12:00 PM                     02:00 AM
# 348  (212) 371-8844                     12:00 PM                     11:00 PM
# 349  (212) 392-5978                     12:00 PM                     12:30 AM
# 350  (212) 956-2155                     11:00 AM                     02:00 AM
# 351  (212) 966-9839                     11:30 AM                     05:00 AM
# 353  (212) 332-7620                     09:30 AM                     11:00 PM
# 355  (212) 352-1700                     11:30 AM                     11:30 PM
# 356  (718) 384-5054                     11:00 AM                     12:00 AM
# 357  (212) 206-9330                     05:00 PM                     11:00 PM
# 359  (212) 260-6481                     11:00 AM                     02:00 AM
# 360  (212) 254-7000                     09:00 AM                     11:00 PM
# 369  (718) 596-6700                     11:30 AM                     10:00 PM
# 370  (212) 708-7460                     07:30 AM                     03:00 PM
# 372  (212) 480-9800                     04:00 PM                     04:00 AM
# 374  (212) 473-5150                     06:00 AM                     11:00 PM
# 375  (212) 988-0002                     04:00 PM                     11:30 PM
# 376  (212) 888-3828                     12:00 PM                     11:00 PM
# 377  (212) 674-4500                     12:00 PM                     02:00 AM
# 380  (212) 221-9002                     11:00 AM                     11:00 PM
# 381  (212) 418-1260                     12:00 PM                     02:00 AM
# 382  (212) 744-0210                     07:30 PM                     11:30 PM
# 383  (212) 695-9694                     04:30 PM                     11:00 PM
# 384  (212) 343-4255                     11:00 AM                     11:30 PM
# 387  (212) 966-4100                     11:30 AM                     04:00 AM
# 388  (212) 766-2344                     03:00 PM                     11:30 PM
# 391  (212) 925-8923                     06:00 PM                     11:30 PM
# 392  (646) 602-6263                     09:00 AM                     11:00 PM
# 396  (212) 627-7575                     10:00 AM                     12:00 AM
#
#     rtable_Sunday Opening time rtable_Sunday Closing time
# 0                     11:00 AM                   09:00 PM
# 1                     10:30 AM                   11:00 PM
# 2                     11:00 AM                   09:00 PM
# 8                     12:00 PM                   11:00 PM
# 9                     07:00 AM                   01:00 AM
# 10                    08:30 AM                   09:00 PM
# 12                    11:00 AM                   10:00 PM
# 13                    11:30 AM                   10:30 PM
# 14                    11:45 AM                   11:00 PM
# 15                    11:00 AM                   07:00 PM
# 23                    12:00 PM                   10:00 PM
# 26                    11:30 AM                   10:00 PM
# 28                    11:30 AM                   03:00 PM
# 30                    10:00 AM                   10:00 PM
# 32                    11:30 AM                   09:30 PM
# 34                    07:30 AM                   10:30 PM
# 36                    05:00 PM                   10:00 PM
# 40                    11:00 AM                   09:30 PM
# 43                    07:00 AM                   10:30 PM
# 45                      CLOSED                     CLOSED
# 54                    11:00 AM                   11:00 PM
# 56                    11:00 AM                   10:30 PM
# 57                    11:30 AM                   10:00 PM
# 58                    10:00 AM                   10:00 PM
# 60                    06:00 PM                   10:00 PM
# 61                    08:00 AM                   12:00 AM
# 62                    08:30 AM                   05:00 PM
# 63                    07:00 AM                   11:00 PM
# 64                    12:00 PM                   11:00 PM
# 65                    07:00 AM                   11:00 PM
# ..                         ...                        ...
# 343                   11:00 AM                   10:30 PM
# 344                   11:00 AM                   10:30 PM
# 345                   12:00 PM                   10:00 PM
# 348                   12:00 PM                   10:30 PM
# 349                   12:00 PM                   11:00 PM
# 350                   11:00 AM                   12:00 AM
# 351                   11:30 AM                   01:00 AM
# 353                   09:30 AM                   09:00 PM
# 355                   11:30 AM                   10:30 PM
# 356                   11:00 AM                   11:00 PM
# 357                   05:00 PM                   10:30 PM
# 359                   11:00 AM                   02:00 AM
# 360                   09:00 AM                   10:00 PM
# 369                   11:30 AM                   10:00 PM
# 370                   07:30 AM                   03:00 PM
# 372                   04:00 PM                   01:00 AM
# 374                   06:00 AM                   11:00 PM
# 375                   04:00 PM                   10:00 PM
# 376                   12:00 PM                   10:00 PM
# 377                   12:00 PM                   12:00 AM
# 380                   11:00 AM                   10:00 PM
# 381                   12:00 PM                   11:00 PM
# 382                   02:00 PM                   10:00 PM
# 383                   04:30 PM                   10:30 PM
# 384                   11:00 AM                   10:30 PM
# 387                   12:00 PM                   11:00 PM
# 388                   03:00 PM                   10:00 PM
# 391                   06:00 PM                   11:30 PM
# 392                   09:00 AM                   06:00 PM
# 396                   10:00 AM                   11:00 PM
#
# [200 rows x 20 columns]

# %%
del F['_id']
del F['ltable_Id']
del F['rtable_Id']

# %% [markdown]
# # Project Stage 4 - Data Merging
# Please find the code for the Data Merging part of Stage 4 below.

# %%
p4 = pd.DataFrame(columns=['Name', 'Address','Cuisines','Take Out','Phone',
                                          'Saturday Opening time','Saturday Closing time','Sunday Opening time',
                                          'Sunday Closing time'])

# %%
def name_merger(row) :
    return row['ltable_Name'][:1].upper()+row['ltable_Name'][1:] if len(row['ltable_Name']) >= len(row['rtable_Name'])\
    else row['rtable_Name'][:1].upper()+row['rtable_Name'][1:] 

def address_merger(row) :
    return row['ltable_Address'].title() if len(row['ltable_Address']) >= len(row['rtable_Address']) \
    else row['rtable_Address'].title()

def cuisine_merger(row):
    result = set()
    union1 = row['ltable_Cuisines'].split(';')
    union1 = [x.lower() for x in union1]
    union2 = row['rtable_Cuisines'].split(';')
    union2 = [x.lower() for x in union2]
    if len(union1)>=len(union2):
        result.update(union1)
    else:
        result.update(union2)
    return "; ".join([x.title() for x in list(result)])

def takeout_merger(row) :
    if row['ltable_Take Out'] == 'Yes' or row['rtable_Take Out'] == 'Yes' :
        return 'Yes'
    else :
        return 'No'

def phone_merger(row) :
    return row['ltable_Phone'] if len(row['ltable_Phone']) >= len(row['rtable_Phone']) \
    else row['rtable_Phone']    
    
def sat_open_merger(row) :
    if row['ltable_Saturday Opening time'].lower() == 'nan' :
        return row['rtable_Saturday Opening time']
    if row['rtable_Saturday Opening time'].lower() == 'nan' :
        return row['ltable_Saturday Opening time']
    if row['rtable_Saturday Opening time'].lower() == 'closed' or row['ltable_Saturday Opening time'].lower() == 'closed':
        return 'Closed'
    return row['ltable_Saturday Opening time'] if len(row['ltable_Saturday Opening time']) <= len(row['rtable_Saturday Opening time']) \
    else row['rtable_Saturday Opening time']  

def sat_close_merger(row) :
    if row['ltable_Saturday Closing time'].lower() == 'nan' :
        return row['rtable_Saturday Closing time']
    if row['rtable_Saturday Closing time'].lower() == 'nan' :
        return row['ltable_Saturday Closing time']
    if row['rtable_Saturday Closing time'].lower() == 'closed' or row['ltable_Saturday Closing time'].lower() == 'closed':
        return 'Closed'
    return row['ltable_Saturday Closing time'] if len(row['ltable_Saturday Closing time']) <= len(row['rtable_Saturday Closing time']) \
    else row['rtable_Saturday Closing time']  

def sun_open_merger(row) :
    if row['ltable_Sunday Opening time'].lower() == 'nan' :
        return row['rtable_Sunday Opening time']
    if row['rtable_Sunday Opening time'].lower() == 'nan' :
        return row['ltable_Sunday Opening time']
    if row['rtable_Sunday Opening time'].lower() == 'closed' or row['ltable_Sunday Opening time'].lower() == 'closed':
        return 'Closed'
    return row['ltable_Sunday Opening time'] if len(row['ltable_Sunday Opening time']) <= len(row['rtable_Sunday Opening time']) \
    else row['rtable_Sunday Opening time']  
    
def sun_close_merger(row):
    if row['ltable_Sunday Closing time'].lower() == 'nan' :
        return row['rtable_Sunday Closing time']
    if row['rtable_Sunday Closing time'].lower() == 'nan' :
        return row['ltable_Sunday Closing time']
    if row['rtable_Sunday Closing time'].lower() == 'closed' or row['ltable_Sunday Closing time'].lower() == 'closed':
        return 'Closed'
    return row['ltable_Sunday Closing time'] if len(row['ltable_Sunday Closing time']) <= len(row['rtable_Sunday Closing time']) \
    else row['rtable_Sunday Closing time']

# %%
p4['Name'] = F.apply(name_merger,axis =1)
p4['Address'] = F.apply(address_merger,axis =1)
p4['Cuisines'] = F.apply(cuisine_merger,axis =1)
p4['Take Out'] = F.apply(takeout_merger,axis =1)
p4['Phone'] = F.apply(phone_merger,axis =1)
p4['Saturday Opening time'] = F.apply(sat_open_merger,axis =1)
p4['Saturday Closing time'] = F.apply(sat_close_merger,axis =1)
p4['Sunday Opening time'] = F.apply(sun_open_merger,axis =1)
p4['Sunday Closing time'] = F.apply(sun_close_merger,axis =1)

# %%
p4.head(100)
# Out:
#                                          Name  \
# 0                        Shanghai asian manor
# 1                                 Shake shack
# 2                                   Blue maiz
# 8                                 Barn joo 35
# 9                  Southgate bar & restaurant
# 10                                 Friedman's
# 12                                 Boulud sud
# 13               Rosa mexicano - union square
# 14                            Benoit new york
# 15                       The original soupman
# 23                                     Limani
# 26                                Kung fu tea
# 28                            Battery gardens
# 30                                     Upland
# 32                          Ristorante morini
# 34                                    Perrine
# 36                             Ninja new york
# 40                              Rossopomodoro
# 43                            Jams restaurant
# 45               William’s restaurant and bar
# 54                                Zizi limona
# 56                   Excellent dumpling house
# 57                                The red cat
# 58                         Buttermilk channel
# 60                                    Hakubai
# 61                              Marlow & sons
# 62                                  Sadelle's
# 63                                   Asellina
# 64                              Victor's cafe
# 65                         The mercer kitchen
# ..                                        ...
# 155                               Clover club
# 156                                    Tavola
# 157                                  Morimoto
# 158                          Brasserie cognac
# 159                               Tehuitzingo
# 160                         Cheeky sandwiches
# 162                       David burke kitchen
# 164                                Casa adela
# 165                      The russian tea room
# 166                           Kellari taverna
# 168                           Dadong new york
# 169                                     Orsay
# 171                                  Toasties
# 172                                 Distilled
# 175                                     Palma
# 176                Sant ambroeus west village
# 181                         Fedora restaurant
# 193          Vegan Options; Vegetarian Friendly; Indian      Yes
# 194                                              French       No
# 195                          Mediterranean; Cafe; Greek      Yes
# 196                              Japanese; Sushi; Asian      Yes
# 198                             Barbecue; Korean; Asian      Yes
# 200                             Moroccan; Mediterranean      Yes
# 201                  Sandwiches; Burgers; Chicken Wings      Yes
# 204  Gluten Free Options; Vegetarian Friendly; American      Yes
#
#                Phone Saturday Opening time Saturday Closing time  \
# 0    +1 212-766-6311              11:00 AM              10:00 PM
# 1    +1 646-747-8770              10:30 AM              11:00 PM
# 2    +1 212-704-2106              11:00 AM              10:00 PM
# 8    +1 212-564-4430              12:00 PM              02:00 AM
# 9    +1 212-484-5120              07:00 AM              10:30 PM
# 10   +1 212-971-9400              08:30 AM              10:00 PM
# 12   +1 212-595-1313              05:00 PM              11:00 PM
# 13   +1 212-533-3350              11:30 AM              11:30 PM
# 14   +1 646-943-7373              11:45 AM              11:00 PM
# 15   +1 212-956-0900              11:00 AM              08:00 PM
# 23   +1 212-858-9200              12:00 PM              12:00 AM
# 26   +1 646-288-4936              11:00 AM              10:00 PM
# 28   +1 212-809-5508              11:30 AM              12:00 AM
# 30   +1 212-686-1006              05:00 PM              11:00 PM
# 32   +1 212-249-0444              04:00 PM              10:30 PM
# 34   +1 212-940-8195              07:00 AM              10:30 PM
# 36   +1 212-274-8500              05:00 PM              11:00 PM
# 40   +1 212-229-2560              09:00 AM              11:00 PM
# 43   +1 212-703-2007              07:00 AM              11:00 PM
# 45   +1 212-859-2200                Closed                Closed
# 54   +1 347-763-1463              11:30 AM              11:00 PM
# 56   +1 212-989-8885              11:00 AM              11:00 PM
# 57   +1 212-242-1308              05:30 PM              11:00 PM
# 58   +1 718-852-8490              05:00 PM              11:30 PM
# 60   +1 212-885-7111              11:45 AM              10:00 PM
# 61   +1 718-384-1441              08:00 AM              12:00 AM
# 62   +1 212-776-4926              08:30 AM              08:30 PM
# 63   +1 212-317-2908              07:00 AM              11:30 PM
# 64   +1 212-586-7714              11:45 AM              12:00 AM
# 65   +1 212-966-5454              07:00 AM              01:00 AM
# ..               ...                   ...                   ...
# 155  +1 718-855-7939              10:30 AM              04:00 AM
# 156  +1 212-273-1181              02:00 PM              11:00 PM
# 157  +1 212-989-8883              05:30 PM              12:00 AM
# 158  +1 212-757-3600              10:00 AM              12:00 AM
# 159  +1 212-397-5956              08:30 AM              11:30 PM
# 160  +1 646-504-6816              07:00 AM              12:00 AM
# 162  +1 212-201-9119              11:00 AM              11:00 PM
# 164  +1 212-473-1882              07:00 AM              11:00 PM
# 165  +1 212-581-7100              11:00 AM              11:30 PM
# 166  +1 212-221-0144              11:30 AM              12:00 AM
# 168  +1 212-355-9600              11:30 AM              10:30 PM
# 169  +1 212-517-6400              05:30 PM              11:00 PM
# 171  +1 212-398-4900              07:00 AM              05:00 PM
# 172  +1 646-809-9490              11:00 AM              02:00 AM
# 175  +1 212-691-2223              05:00 PM              11:00 PM
# 176  +1 212-604-9254              09:00 AM              11:00 PM
# 181  +1 212-242-9691              05:30 PM              02:00 AM
# 182  +1 212-736-3000              05:00 PM              10:30 PM
# 183  +1 212-219-0900              05:00 PM              10:30 PM
# 185  +1 212-299-3900              11:45 AM              11:00 PM
# 186  +1 212-299-3900              11:45 AM              11:00 PM
# 192  +1 212-260-2914              01:00 PM              04:00 AM
# 193  +1 212-777-2888              11:30 AM              05:00 AM
# 194  +1 212-966-3518              05:00 PM              01:00 AM
# 195  +1 212-226-2701              07:00 AM              08:00 PM
# 196  +1 212-397-0404              07:00 AM              02:00 AM
# 198  +1 212-582-4446              12:00 PM              11:00 PM
# 200  +1 212-873-2300              05:00 PM              02:00 AM
# 201  +1 212-348-2627              11:00 AM              10:00 PM
# 204  +1 212-634-4040              07:30 AM              11:00 PM
#
#     Sunday Opening time Sunday Closing time
# 0              11:00 AM            09:00 PM
# 1              10:30 AM            11:00 PM
# 2              11:00 AM            09:00 PM
# 8              12:00 PM            11:00 PM
# 9              07:00 AM            10:30 PM
# 10             08:30 AM            09:00 PM
# 12             05:00 PM            10:00 PM
# 13             11:30 AM            04:00 PM
# 14             11:45 AM            11:00 PM
# 15             11:00 AM            07:00 PM
# 23             12:00 PM            10:00 PM
# 26             11:00 AM            10:00 PM
# 28             11:30 AM            12:00 AM
# 30             05:00 PM            10:00 PM
# 32             11:30 AM            09:30 PM
# 34             07:00 AM            10:30 PM
# 36             05:00 PM            10:00 PM
# 40             09:00 AM            11:00 PM
# 43             07:00 AM            10:30 PM
# 45               Closed              Closed
# 54             11:30 AM            11:00 PM
# 56             11:00 AM            10:30 PM
# 57             05:00 PM            10:00 PM
# 58             05:00 PM            10:00 PM
# 60             06:00 PM            10:00 PM
# 61             08:00 AM            12:00 AM
# 62             08:30 AM            05:00 PM
# 63             07:00 AM            10:00 PM
# 64             11:45 AM            11:00 PM
# 65             07:00 AM            11:00 PM
# ..                  ...                 ...
# 155            10:30 AM            02:00 AM
# 156            02:00 PM            11:00 PM
# 157            05:30 PM            10:00 PM
# 158            10:00 AM            12:00 AM
# 159            08:30 AM            11:30 PM
# 160            07:00 AM            09:00 PM
# 162            11:00 AM            10:00 PM
# 164            07:00 AM            11:00 PM
# 165            11:00 AM            11:30 PM
# 166            11:30 AM            11:00 PM
# 168            11:30 AM            10:00 PM
# 169            11:00 AM            09:30 PM
# 171            07:00 AM            05:00 PM
# 172            11:00 AM            11:00 PM
# 175            05:00 PM            10:00 PM
# 176            09:00 AM            11:00 PM
# 181            05:30 PM            01:00 AM
# 182            05:00 PM            09:30 PM
# 183            05:00 PM            09:00 PM
# 185            11:45 AM            11:00 PM
# 186            11:45 AM            11:00 PM
# 192            01:00 PM            04:00 AM
# 193            11:30 AM            05:00 AM
# 194            05:00 PM            12:00 AM
# 195            08:00 AM            08:00 PM
# 196            07:00 AM            12:00 AM
# 198            12:00 PM            10:30 PM
# 200            05:00 PM            12:00 AM
# 201            11:00 AM            10:00 PM
# 204            07:30 AM            10:00 PM
#
# [100 rows x 9 columns]

# %%
p4.to_csv("E.csv",index = False,encoding = 'cp1252')
